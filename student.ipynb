# %% [markdown]
# ## Final Project Submission
#
#
# * Student name: Tracy Otieno
# * Student pace: Full Time
# * Scheduled project review date/time: 26th September, 2024 (12:00 p.m. EAT)
# * Instructor name: Maryann Mwikali
# * Blog post URL:

# %% [markdown]
# # Data Understanding
# In this section, I will import and explore the dataset so as to get insight on how the data is structured, the quality of the data, and its content

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#Import libraries that will be useful for data manipulation and data visualization

# %%
df = pd.read_csv('AviationData.csv', encoding ='latin-1', low_memory=False)

#Load my csv file

# %%
df.head()

#Show the first 5 rows in my dataset to help me understand the structure, content, and format of my data.
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
df.tail()

#Show the last 5 rows in my dataset
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#             Location        Country Latitude Longitude Airport.Code  \
# 88884  Annapolis, MD  United States      NaN       NaN          NaN
# 88885    Hampton, NH  United States      NaN       NaN          NaN
# 88886     Payson, AZ  United States  341525N  1112021W          PAN
# 88887     Morgan, UT  United States      NaN       NaN          NaN
# 88888     Athens, GA  United States      NaN       NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 88884          NaN  ...          Personal                 NaN
# ...

# %%
df.info()

#This will give me a summary of my data i.e. column names, non-null values, dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
df.describe()

#Displays descriptive staatistics for numerical columns only
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
df.shape

# Displays the shape of the dataframe, in this case, it contains 88889 rows and 31 columns
# Out:
# (88889, 31)

# %% [markdown]
# # Data Preparation
# In this section, clean the data by dropping columns with a lot of missing values, identifying and removing duplicates, and filling missing values in numerical columns

# %% [markdown]
# #### Dropping columns with missing values

# %%
# Calculate the percentage of missing values per column
missing_percentage = df.isnull().sum() / len(df) * 100

#Identify the columns I want to drop i.e columns with over 60% of missing values
dropped_columns = missing_percentage[missing_percentage > 60].index.tolist()

df = df.drop(columns=dropped_columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Airport.Code            50249 non-null  object
#  7   Airport.Name            52790 non-null  object
#  8   Injury.Severity         87889 non-null  object
#  9   Aircraft.damage         85695 non-null  object
#  10  Registration.Number     87572 non-null  object
#  11  Make                    88826 non-null  object
#  12  Model                   88797 non-null  object
#  13  Amateur.Built           88787 non-null  object
# ...

# %% [markdown]
# #### Finding and removing duplicates

# %%
# Dictionary comprehension to identify the columns that have duplicates, and the sum of duplicates in each column

duplicates = {col: df.duplicated(subset=col).sum() for col in df.columns}
duplicates
# Out:
# {'Event.Id': 938,
#  'Investigation.Type': 88887,
#  'Accident.Number': 26,
#  'Event.Date': 74107,
#  'Location': 61130,
#  'Country': 88669,
#  'Airport.Code': 78513,
#  'Airport.Name': 64017,
#  'Injury.Severity': 88779,
#  'Aircraft.damage': 88884,
#  'Registration.Number': 9783,
#  'Make': 80651,
#  'Model': 76570,
#  'Amateur.Built': 88886,
#  'Number.of.Engines': 88881,
#  'Engine.Type': 88875,
#  'Purpose.of.flight': 88862,
#  'Total.Fatal.Injuries': 88763,
#  'Total.Serious.Injuries': 88838,
#  'Total.Minor.Injuries': 88831,
#  'Total.Uninjured': 88509,
#  'Weather.Condition': 88884,
#  'Broad.phase.of.flight': 88876,
#  'Report.Status': 71813,
#  'Publication.Date': 85964}

# %%
# Drop duplicates in the Event ID column & Accident Number column

df = df.drop_duplicates(subset='Event.Id').reset_index(drop=True)
df = df.drop_duplicates(subset='Accident.Number').reset_index(drop=True)

# %% [markdown]
# #### Filling Columns With Missing Values

# %%
df['Total.Fatal.Injuries'] = df['Total.Fatal.Injuries'].fillna(df['Total.Fatal.Injuries'].median())

# %%
df['Total.Serious.Injuries'] = df['Total.Serious.Injuries'].fillna(df['Total.Serious.Injuries'].median())

# %%
df['Total.Minor.Injuries'] = df['Total.Minor.Injuries'].fillna(df['Total.Minor.Injuries'].median())

# %%
df['Total.Uninjured'] = df['Total.Uninjured'].fillna(df['Total.Uninjured'].median())

# %% [markdown]
# # Data Visualization
# In this section, data is visualized for easier interpretation

# %% [markdown]
# #####  1. Accident Trends Over Time

# %%
# Convert Event date to datetime format
df['Event.Date'] = pd.to_datetime(df['Event.Date'], errors = 'coerce')

# Create a new column year
df['Year'] = df['Event.Date'].dt.year

# Filter my Year column to only include data from 1962 onwards
df = df[df['Year'] >= 1962]

# %%
# Plot a line graph to show trends of accident over time to understand whether they have increased or decreased over time.
accidents_per_year = df.groupby('Year')['Accident.Number'].count()

plt.figure(figsize=(10, 6))
plt.plot(accidents_per_year.index, accidents_per_year.values, linestyle='-', color='b')
plt.title('Total Number of Accidents Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

# %% [markdown]
# #### Analysis of Accident Trends Over Time
#
# The chart above shows that from 1962 to 1981, the number of recorded accidents was relatively low. It is important to consider the possibility that data collection and reporting methods during this period may not have been as comprehensive as in later years. After 1982, the data indicates a steady decline in the number of accidents. This trend could be associated with multiple factors, including advancements in aviation technology, changes in safety regulations, or improved operational practices. Further analysis may be needed to understand the specific reasons behind this decline.

# %% [markdown]
# #### 2. Aircraft Makes and Accident Records

# %%
# Change the column titles to avoid having more than 1 column with the same name but different cases

df['Make'] = df['Make'].str.title()

# %%
# Filter the top 10 most common makes that I will use in my data analysis

df['Make'].value_counts().head(10)
# Out:
# Cessna      26839
# Piper       14744
# Beech        5332
# Bell         2706
# Boeing       2652
# Mooney       1322
# Robinson     1223
# Grumman      1158
# Bellanca     1033
# Hughes        931
# Name: Make, dtype: int64

# %%
# Group the dataframe by 'Make' and calculate the number of unique accidents for each make
accidents_by_make = df.groupby('Make')['Accident.Number'].nunique()

# Returns top 10 aircraft 'Makes' with the highest number of uniques accidents
top_10_makes = accidents_by_make.nlargest(10)

# Plot a bar graph to visualize the data
plt.figure(figsize=(10, 6))
top_10_makes.plot(kind='bar', color='skyblue')
plt.title('Top 10 Aircraft Make by Number of Accidents')
plt.xlabel('Aircraft Make')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### Analysis of Aircraft Makes and Accident Records
#
# The bar chart presented highlights the most common aircraft makes within our dataset. Notably, these makes also correspond to a significant number of recorded accidents. This correlation suggests a potential need for further investigation into the safety records and operational practices associated with these aircraft.

# %% [markdown]
# #### 3.  Top 10 Common Aircraft Makes and Aircraft Damage

# %%
# Identify the top 10 aircraft makes
top_makes = df['Make'].value_counts().nlargest(10).index

# Filter my dataframe
top_makes_df = df[df['Make'].isin(top_makes)]

#Group by Model and Aircraft Damage
damage_counts = top_makes_df.groupby(['Make', 'Aircraft.damage']).size().unstack(fill_value=0)

#Plot the stacked bar chart
damage_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')

plt.title('Stacked Bar Chart of Aircraft Damage by Top 10 Makes')
plt.xlabel('Aircraft Make')
plt.ylabel('Number of Damage Incidents')
plt.xticks(rotation=45)
plt.legend(title='Aircraft Damage')
plt.show()

# %% [markdown]
# #### Analysis for Top 10 Most Common Aircraft Make and Aircraft Damage
#
# The analysis reveals that the top 10 aircraft makes with the highest recorded accidents as seen in the previous bar chart are: Cessna, Piper, Beech, Boeing, Bell, Mooney, Robinson, Grumman, Bellanca, and Hughes, with Cessna, Piper, and Beech( In that order) suggesting a potential correlation between their prevalence and operational use.
#
# When assessing aircraft damage, the ranking shifts slightly to Cessna, Piper, Beech, Bell, Mooney, Robinson, Boeing, Grumman, Bellanca, and Hughes( In that order); while Cessna, Piper, and Beech remain in the top three, Boeing ranks lower, indicating variations in damage severity.

# %% [markdown]
# #### 4. Top 10 Most Common Models and Number of Accidents

# %%
# Group by Model and calculate the number of unique accidents for each model
accidents_by_model = df.groupby('Model')['Accident.Number'].nunique()

# Select the top 10 models with the highest number of accidents
top_10_models = accidents_by_model.nlargest(10)

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_10_models.index, top_10_models.values, color='green') 
plt.title('Top 10 Aircraft Models by Number of Accidents')
plt.xlabel('Aircraft Model')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=0) 
plt.show()

# %% [markdown]
# #### Analysis of Aircraft Model and Number of Accidents
#
# The analysis indicates that the most common aircraft models are also those associated with the highest number of accidents, highlighting a positive correlation between the prevalence of these models and their involvement in incidents. This suggests that increased operational use may contribute to higher accident rates.

# %% [markdown]
# #### 5. Top 10 Common Aircraft Models and Aircraft Damage

# %%
# Identify the top 10 aircraft models
top_models = df['Model'].value_counts().nlargest(10).index

## Filter my dataframe
top_models_df = df[df['Model'].isin(top_models)]

# Group by Model and Aircraft Damage
damage_counts = top_models_df.groupby(['Model', 'Aircraft.damage']).size().unstack(fill_value=0)

# Plot the stacked bar chart
damage_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')

plt.title('Stacked Bar Chart of Aircraft Damage by Top 10 Common Models')
plt.xlabel('Aircraft Model')
plt.ylabel('Number of Damage Incidents')
plt.xticks(rotation=45)
plt.legend(title='Aircraft Damage')
plt.show()

# %% [markdown]
# #### Analysis for Top 10 Most Common Aircraft Models and Aircraft Damage
#
# The previous analysis identified the top 10 aircraft models with the highest recorded accidents, as illustrated in the previous bar chart: 152, 172, 172N, PA-28-140, 150, 172M, 172P, 182, 180, and 150M. This ranking suggests a potential correlation between the prevalence of these models and their involvement in accidents, indicating that higher usage may be associated with increased accident rates.
#
# When assessing aircraft damage, the ranking reflects the same order: 152, 172, 172N, PA-28-140, 150, 172M, 172P, 182, 180, and 150M.
#
# The data indicates a correlation between accident frequency and the severity of damage for certain aircraft models. This suggests that models that are frequently used and involved in incidents may also experience significant damage during accidents.

# %% [markdown]
# #### 6. Types of Investigation Conducted

# %%
# Counts the unique values in the 'Investigation.Type column'
investigation_counts = df['Investigation.Type'].value_counts()

# %%
#Plot a pie chart to display investigation types( accident, incident)

fig, ax = plt.subplots(figsize=(10, 6))
ax.pie(investigation_counts, labels=investigation_counts.index, autopct='%1.1f%%', startangle=90)
ax.set_title('Distribution of Investigation Types')
ax.axis('equal')  
plt.show()

# %% [markdown]
# #### 7. Relationship Between Engine Type and Accident Per Year

# %%
# Groups data by Year and Engine Type
accidents_per_year_engine = df.groupby(['Year', 'Engine.Type']).size().unstack(fill_value=0)

# Plot line graphs
plt.figure(figsize=(10, 6))
accidents_per_year_engine.plot(kind='line', figsize=(14, 7))

plt.title('Accidents per Year by Engine Type')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.legend(title='Engine Type')
plt.show()

# %% [markdown]
# #### Analysis of Accidents Per Year Based on Engine Type
#
# The analysis of aircraft engine types and their associated accident counts reveals that Reciprocating engines dominate with the highest number of accidents. This significant figure suggests that while reciprocating engines are widely used, their safety performance requires urgent attention to mitigate risks.

# %% [markdown]
# ####  8.  Aircraft damage at different flight phases

# %%
# Group data by Broad phase of flight and Aircraft damage
damage_counts = df.groupby(['Broad.phase.of.flight', 'Aircraft.damage']).size().unstack()

# Plot a stacked bar chart
damage_counts.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.title('Aircraft Damage by Broad Phase of Flight')
plt.xlabel('Broad Phase of Flight')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45)
plt.legend(title='Aircraft Damage')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analysis of aircraft damage at different flight phases
# The analysis of aircraft accidents categorized by flight phase and damage level reveals that the Landing, Takeoff, Cruise, and Approach phases are associated with a high frequency of significant accidents, including many classified as Destroyed or Substantial damage. This indicates a critical need for enhanced safety measures during these phases.

# %% [markdown]
# #### 9. Accidents and weather conditions

# %%
# Renaming the values in my column to be easily understood
df['Weather.Condition'] = df['Weather.Condition'].replace({
    'VMC': 'Visual Meteorological Conditions',
    'IMC': 'Instrument Meteorological Conditions',
    'UNK': 'Unknown'
})

# %%
# Group weather condition and number of accidents
accidents_by_weather = df.groupby('Weather.Condition')['Accident.Number'].nunique().reset_index()
accidents_by_weather.columns = ['Weather Condition', 'Number of Accidents']

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(accidents_by_weather['Weather Condition'], accidents_by_weather['Number of Accidents'], color='blue')
plt.title('Number of Unique Accidents by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Unique Accidents')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Analysis of Number of accidents by weather condition
#
# From the above bar chart, we see that more accidents occur in Visual Meteorological Conditions than in Instrument Meteorological Conditions. This highlights the importance of ongoing analysis and training and safety initiatives.

# %% [markdown]
# #### 10. Pie Chart Showing Total Injury Types

# %%
injury_data = df[['Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured']].sum()

fig, ax = plt.subplots(figsize=(10, 6))

ax.pie(injury_data, labels=injury_data.index, autopct='%1.1f%%', startangle=90)

ax.set_title('Injuries')
ax.axis('equal')  

plt.show()
